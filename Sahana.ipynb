# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahana123071/college-lateness-predictor/blob/main/Sahana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# minutes before 9:00 AM that you left the room
minutes_before_class = [5, 10, 15, 20, 25, 30, 8, 12, 35, 18, 22, 40, 6, 28]

# was I late that day?
result = ["Late","Late","Late","On Time","On Time","On Time","Late","Late",
          "On Time","Late","On Time","On Time","Late","On Time"]
import pandas as pd
df = pd.DataFrame({"minutes_before": minutes_before_class, "result": result})
df
from sklearn.linear_model import LogisticRegression

X = df[["minutes_before"]]
y = df["result"]

model = LogisticRegression()
model.fit(X, y)
model.predict([[15]])   # "if I leave 15 min before class, will I be late?"
for m in range(0, 45, 5):
    print(m, "min before ->", model.predict([[m]])[0])
# Out:
# 0 min before -> Late
# 5 min before -> Late
# 10 min before -> Late
# 15 min before -> Late
# 20 min before -> On Time
# 25 min before -> On Time
# 30 min before -> On Time
# 35 min before -> On Time
# 40 min before -> On Time
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# Answers

# %% [markdown]
# Why i picked this data set is it is quite easy ,and i could track it even for myself ,and i can check the ouput easily .
# I have built a model to track/find out the timings ,at what time if i leave the room ,i will reach clg on time (15 - 20 mins) is good time to reach on time .
